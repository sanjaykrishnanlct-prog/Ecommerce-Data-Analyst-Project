# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\gokul\\downloads'

# %%
cd downloads
# Out:
# [WinError 2] The system cannot find the file specified: 'downloads'
# C:\Users\gokul\downloads

# %%
orders=pd.read_excel('Orders.xlsx')
customers=pd.read_excel('Customers.xlsx')
payments=pd.read_excel('Payments.xlsx')

# %%
orders.head()
# Out:
#   Order_ID Customer_ID  Order_Date Product     Category  Quantity  Price  \
# 0   O00001       C0256  2025-07-03  Laptop  Electronics         5  45491
# 1   O00002       C0036  2025-07-07   Phone  Electronics         5  15611
# 2   O00003       C0133  2025-05-14   Phone  Electronics         2  34454
# 3   O00004       C0201  2025-06-09   Chair    Furniture         3  29117
# 4   O00005       C0259  2025-11-22   Phone  Electronics         3  36928
#
#    Discount       State   Sales    Profit
# 0       0.0  Tamil Nadu  227455  17528.03
# 1      15.0   Karnataka   78055  14592.50
# 2       5.0   Karnataka   68908  16247.06
# 3       NaN  Tamil Nadu   87351  11904.62
# 4       5.0      Kerala  110784  17232.64

# %%
customers.head()
# Out:
#   Customer_ID Customer_Name  Age  Gender     City           State
# 0       C0001    Customer_1   40    Male  City_16          Kerala
# 1       C0002    Customer_2   48    Male   City_6      Tamil Nadu
# 2       C0003    Customer_3   51  Female  City_11       Telangana
# 3       C0004    Customer_4   54  Female  City_17  Andhra Pradesh
# 4       C0005    Customer_5   42  Female   City_2          Kerala

# %%
payments.head()
# Out:
#   Payment_ID Order_ID Payment_Mode  Amount
# 0     P00001   O00001          UPI   60428
# 1     P00002   O00002          UPI   18703
# 2     P00003   O00003   NetBanking   70871
# 3     P00004   O00004   NetBanking   15394
# 4     P00005   O00005          UPI   70769

# %%
orders.shape
# Out:
# (1000, 11)

# %%
customers.shape
# Out:
# (300, 6)

# %%
payments.shape
# Out:
# (1000, 4)

# %%
orders.dtypes
# Out:
# Order_ID        object
# Customer_ID     object
# Order_Date      object
# Product         object
# Category        object
# Quantity         int64
# Price            int64
# Discount       float64
# State           object
# Sales            int64
# Profit         float64
# dtype: object

# %%
customers.dtypes
# Out:
# Customer_ID      object
# Customer_Name    object
# Age               int64
# Gender           object
# City             object
# State            object
# dtype: object

# %%
payments.dtypes
# Out:
# Payment_ID      object
# Order_ID        object
# Payment_Mode    object
# Amount           int64
# dtype: object

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Order_ID     1000 non-null   object
#  1   Customer_ID  1000 non-null   object
#  2   Order_Date   1000 non-null   object
#  3   Product      1000 non-null   object
#  4   Category     1000 non-null   object
#  5   Quantity     1000 non-null   int64
#  6   Price        1000 non-null   int64
#  7   Discount     788 non-null    float64
#  8   State        1000 non-null   object
#  9   Sales        1000 non-null   int64
#  10  Profit       1000 non-null   float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 86.1+ KB

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Customer_ID    300 non-null    object
#  1   Customer_Name  300 non-null    object
#  2   Age            300 non-null    int64
#  3   Gender         300 non-null    object
#  4   City           300 non-null    object
#  5   State          300 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ KB

# %%
payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Payment_ID    1000 non-null   object
#  1   Order_ID      1000 non-null   object
#  2   Payment_Mode  1000 non-null   object
#  3   Amount        1000 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 31.4+ KB

# %%
orders.isnull().sum()
# Out:
# Order_ID         0
# Customer_ID      0
# Order_Date       0
# Product          0
# Category         0
# Quantity         0
# Price            0
# Discount       212
# State            0
# Sales            0
# Profit           0
# dtype: int64

# %%
customers.isnull().sum()
# Out:
# Customer_ID      0
# Customer_Name    0
# Age              0
# Gender           0
# City             0
# State            0
# dtype: int64

# %%
payments.isnull().sum()
# Out:
# Payment_ID      0
# Order_ID        0
# Payment_Mode    0
# Amount          0
# dtype: int64

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
payments.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders['Discount']=orders['Discount'].fillna(0)

# %%
orders.drop_duplicates()
# Out:
#     Order_ID Customer_ID  Order_Date Product     Category  Quantity  Price  \
# 0     O00001       C0256  2025-07-03  Laptop  Electronics         5  45491
# 1     O00002       C0036  2025-07-07   Phone  Electronics         5  15611
# 2     O00003       C0133  2025-05-14   Phone  Electronics         2  34454
# 3     O00004       C0201  2025-06-09   Chair    Furniture         3  29117
# 4     O00005       C0259  2025-11-22   Phone  Electronics         3  36928
# ..       ...         ...         ...     ...          ...       ...    ...
# 995   O00996       C0132  2025-06-21   Chair    Furniture         1  46825
# 996   O00997       C0203  2025-02-24   Table    Furniture         3  45095
# 997   O00998       C0042  2025-02-19  Laptop  Electronics         5   7575
# 998   O00999       C0084  2025-02-27   Phone  Electronics         4  19142
# 999   O01000       C0152  2025-08-20   Chair    Furniture         5  40393
#
#      Discount           State   Sales    Profit
# ...

# %%
customers.drop_duplicates()
# Out:
#     Customer_ID Customer_Name  Age  Gender     City           State
# 0         C0001    Customer_1   40    Male  City_16          Kerala
# 1         C0002    Customer_2   48    Male   City_6      Tamil Nadu
# 2         C0003    Customer_3   51  Female  City_11       Telangana
# 3         C0004    Customer_4   54  Female  City_17  Andhra Pradesh
# 4         C0005    Customer_5   42  Female   City_2          Kerala
# ..          ...           ...  ...     ...      ...             ...
# 295       C0296  Customer_296   37    Male   City_1       Telangana
# 296       C0297  Customer_297   24  Female  City_18  Andhra Pradesh
# 297       C0298  Customer_298   63    Male  City_17      Tamil Nadu
# 298       C0299  Customer_299   45  Female  City_12      Tamil Nadu
# 299       C0300  Customer_300   56  Female  City_16      Tamil Nadu
#
# [300 rows x 6 columns]

# %%
payments.drop_duplicates()
# Out:
#     Payment_ID Order_ID Payment_Mode  Amount
# 0       P00001   O00001          UPI   60428
# 1       P00002   O00002          UPI   18703
# 2       P00003   O00003   NetBanking   70871
# 3       P00004   O00004   NetBanking   15394
# 4       P00005   O00005          UPI   70769
# ..         ...      ...          ...     ...
# 995     P00996   O00996         Card   28119
# 996     P00997   O00997          UPI   75766
# 997     P00998   O00998   NetBanking   12830
# 998     P00999   O00999   NetBanking   52805
# 999     P01000   O01000          COD   33442
#
# [1000 rows x 4 columns]

# %%
orders.isnull().sum()
# Out:
# Order_ID       0
# Customer_ID    0
# Order_Date     0
# Product        0
# Category       0
# Quantity       0
# Price          0
# Discount       0
# State          0
# Sales          0
# Profit         0
# dtype: int64

# %%
customers.isnull().sum()
# Out:
# Customer_ID      0
# Customer_Name    0
# Age              0
# Gender           0
# City             0
# State            0
# dtype: int64

# %%
orders['Product'].value_counts()
# Out:
# Product
# Phone     215
# Laptop    200
# Shoes     198
# Chair     194
# Table     193
# Name: count, dtype: int64

# %%
customers['Gender'].value_counts()
# Out:
# Gender
# Female    154
# Male      146
# Name: count, dtype: int64

# %%
payments['Payment_Mode'].value_counts()
# Out:
# Payment_Mode
# Card          256
# COD           254
# NetBanking    250
# UPI           240
# Name: count, dtype: int64

# %%
df=pd.merge(orders,customers,on='Customer_ID',how='left')

# %%
df.head()
# Out:
#   Order_ID Customer_ID  Order_Date Product     Category  Quantity  Price  \
# 0   O00001       C0256  2025-07-03  Laptop  Electronics         5  45491
# 1   O00002       C0036  2025-07-07   Phone  Electronics         5  15611
# 2   O00003       C0133  2025-05-14   Phone  Electronics         2  34454
# 3   O00004       C0201  2025-06-09   Chair    Furniture         3  29117
# 4   O00005       C0259  2025-11-22   Phone  Electronics         3  36928
#
#    Discount     State_x   Sales    Profit Customer_Name  Age  Gender     City  \
# 0       0.0  Tamil Nadu  227455  17528.03  Customer_256   60  Female   City_9
# 1      15.0   Karnataka   78055  14592.50   Customer_36   63    Male  City_20
# 2       5.0   Karnataka   68908  16247.06  Customer_133   59  Female  City_15
# 3       0.0  Tamil Nadu   87351  11904.62  Customer_201   28  Female   City_8
# 4       5.0      Kerala  110784  17232.64  Customer_259   57  Female   City_9
#
#           State_y
# 0       Karnataka
# 1      Tamil Nadu
# ...

# %%
df=pd.merge(df,payments,on='Order_ID',how='left')

# %%
df.head()
# Out:
#   Order_ID Customer_ID  Order_Date Product     Category  Quantity  Price  \
# 0   O00001       C0256  2025-07-03  Laptop  Electronics         5  45491
# 1   O00002       C0036  2025-07-07   Phone  Electronics         5  15611
# 2   O00003       C0133  2025-05-14   Phone  Electronics         2  34454
# 3   O00004       C0201  2025-06-09   Chair    Furniture         3  29117
# 4   O00005       C0259  2025-11-22   Phone  Electronics         3  36928
#
#    Discount     State_x   Sales    Profit Customer_Name  Age  Gender     City  \
# 0       0.0  Tamil Nadu  227455  17528.03  Customer_256   60  Female   City_9
# 1      15.0   Karnataka   78055  14592.50   Customer_36   63    Male  City_20
# 2       5.0   Karnataka   68908  16247.06  Customer_133   59  Female  City_15
# 3       0.0  Tamil Nadu   87351  11904.62  Customer_201   28  Female   City_8
# 4       5.0      Kerala  110784  17232.64  Customer_259   57  Female   City_9
#
#           State_y Payment_ID Payment_Mode  Amount
# ...

# %%
df['Revenue']=df['Quantity']*df['Price']

# %%
df.head()
# Out:
#   Order_ID Customer_ID  Order_Date Product     Category  Quantity  Price  \
# 0   O00001       C0256  2025-07-03  Laptop  Electronics     45491  45491
# 1   O00002       C0036  2025-07-07   Phone  Electronics     15611  15611
# 2   O00003       C0133  2025-05-14   Phone  Electronics     34454  34454
# 3   O00004       C0201  2025-06-09   Chair    Furniture     29117  29117
# 4   O00005       C0259  2025-11-22   Phone  Electronics     36928  36928
#
#    Discount     State_x   Sales    Profit Customer_Name  Age  Gender     City  \
# 0       0.0  Tamil Nadu  227455  17528.03  Customer_256   60  Female   City_9
# 1      15.0   Karnataka   78055  14592.50   Customer_36   63    Male  City_20
# 2       5.0   Karnataka   68908  16247.06  Customer_133   59  Female  City_15
# 3       0.0  Tamil Nadu   87351  11904.62  Customer_201   28  Female   City_8
# 4       5.0      Kerala  110784  17232.64  Customer_259   57  Female   City_9
#
# ...

# %%
df['Order_Date']=pd.to_datetime(df['Order_Date'])

# %%
df['Month']=df['Order_Date'].dt.month_name()

# %%
df['Quarter']=df['Order_Date'].dt.quarter

# %%
df['Revenue'].sum()
# Out:
# np.int64(864393427986)

# %%
df['Order_ID'].count()
# Out:
# np.int64(1000)

# %%
df['Revenue'].mean()
# Out:
# np.float64(864393427.986)

# %%
df.groupby('Product')['Revenue'].sum()
# Out:
# Product
# Chair     167677037479
# Laptop    163211993590
# Phone     187251948157
# Shoes     184322481917
# Table     161929966843
# Name: Revenue, dtype: int64

# %%
df.groupby('State_x')['Revenue'].sum()
# Out:
# State_x
# Andhra Pradesh    173122467215
# Karnataka         169607203672
# Kerala            155106775865
# Tamil Nadu        183196945074
# Telangana         183360036160
# Name: Revenue, dtype: int64

# %%
df.groupby('State_y')['Revenue'].sum()
# Out:
# State_y
# Andhra Pradesh    157273910096
# Karnataka         168299747922
# Kerala            175691173720
# Tamil Nadu        190558095125
# Telangana         172570501123
# Name: Revenue, dtype: int64

# %%
df.rename(columns={'State_x':'Order_State','State_y':'Customer_State'},inplace=True)

# %%
df.columns.tolist()
# Out:
# ['Order_ID',
#  'Customer_ID',
#  'Order_Date',
#  'Product',
#  'Category',
#  'Quantity',
#  'Price',
#  'Discount',
#  'Order_State',
#  'Sales',
#  'Profit',
#  'Customer_Name',
#  'Age',
#  'Gender',
#  'City',
#  'Customer_State',
#  'Payment_ID',
#  'Payment_Mode',
#  'Amount',
#  'Revenue',
#  'Month',
#  'Quarter']

# %%
df.head()
# Out:
#   Order_ID Customer_ID Order_Date Product     Category  Quantity  Price  \
# 0   O00001       C0256 2025-07-03  Laptop  Electronics     45491  45491
# 1   O00002       C0036 2025-07-07   Phone  Electronics     15611  15611
# 2   O00003       C0133 2025-05-14   Phone  Electronics     34454  34454
# 3   O00004       C0201 2025-06-09   Chair    Furniture     29117  29117
# 4   O00005       C0259 2025-11-22   Phone  Electronics     36928  36928
#
#    Discount Order_State   Sales  ...  Age  Gender     City  Customer_State  \
# 0       0.0  Tamil Nadu  227455  ...   60  Female   City_9       Karnataka
# 1      15.0   Karnataka   78055  ...   63    Male  City_20      Tamil Nadu
# 2       5.0   Karnataka   68908  ...   59  Female  City_15      Tamil Nadu
# 3       0.0  Tamil Nadu   87351  ...   28  Female   City_8          Kerala
# 4       5.0      Kerala  110784  ...   57  Female   City_9  Andhra Pradesh
#
#   Payment_ID Payment_Mode Amount     Revenue     Month  Quarter
# ...

# %%
df['Revenue'].sum()
# Out:
# np.int64(864393427986)

# %%
df['Revenue'].mean()
# Out:
# np.float64(864393427.986)

# %%
df['Revenue'].median()
# Out:
# 666698726.5

# %%
df['Revenue'].max()
# Out:
# 2497400676

# %%
df['Revenue'].min()
# Out:
# 430336

# %%
df.groupby('Product')['Revenue'].sum().sort_values(ascending=False)
# Out:
# Product
# Phone     187251948157
# Shoes     184322481917
# Chair     167677037479
# Laptop    163211993590
# Table     161929966843
# Name: Revenue, dtype: int64

# %% [markdown]
# 1. phone = H ighest Revenue
# 2. shoes- 2nd
# 3. chair - 3rd

# %%
df.groupby('Customer_State')['Revenue'].sum().plot(kind='bar',figsize=(8,5))
plt.title('Revenue By State')
plt.show()

# %%
df['Payment_Mode'].value_counts()
# Out:
# Payment_Mode
# Card          256
# COD           254
# NetBanking    250
# UPI           240
# Name: count, dtype: int64

# %%
df['Payment_Mode'].value_counts().plot(kind='pie',autopct="%1.1f%%")
plt.show()

# %%
df.groupby('Customer_Name')['Revenue'].sum().sort_values(ascending=False).head(10)
# Out:
# Customer_Name
# Customer_214    10342640835
# Customer_279     9077934606
# Customer_71      7904462215
# Customer_148     7654873037
# Customer_69      7579378818
# Customer_131     7430546346
# Customer_206     7375974819
# Customer_171     7240322081
# Customer_52      7160943268
# Customer_256     6970537830
# Name: Revenue, dtype: int64

# %%
df.groupby('Age')["Revenue"].sum()
# Out:
# Age
# 18    15387414214
# 19    19491409660
# 20    15288305260
# 21    19349355428
# 22    14348346630
# 23     6005428555
# 24    29890039778
# 25     5668720007
# 26    15063381351
# 27    12310628208
# 28     4656051604
# 29    15979222738
# 30    35071726078
# 31    17101752426
# 32    11480405713
# 33    14838540833
# 34    14891874274
# 35    18360439047
# 36    11948680546
# 37    30819897389
# 38     5894399139
# 39     7404538141
# 40    11212462962
# 41    23948335616
# 42    18150502808
# 43    11317751115
# 44    15743356476
# 45     9310143693
# 46    16673524795
# 47    27897292348
# 48    14047167286
# 49     3788893804
# 50    30628525082
# 51    29487433427
# 52    22191335206
# 53    16203946688
# 54    27863310823
# 55    26092215950
# 56    32743665895
# 57    20965834508
# 58    10707284175
# 59    19272387956
# 60    31204476637
# 61    28029910698
# 62     4110918939
# 63    19242211318
# 64    34660818382
# 65    17649164380
# Name: Revenue, dtype: int64

# %%
df['Age_Group']=pd.cut(df['Age'],bins=[18,25,35,45,60,100],labels=['18-25','26-35','36-45','46-60','60+'])

# %%
df.groupby('Age_Group')["Revenue"].sum()
# Out:
# C:\Users\gokul\AppData\Local\Temp\ipykernel_7800\2864779364.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Age_Group')["Revenue"].sum()
# Age_Group
# 18-25    110041605318
# 26-35    159754022272
# 36-45    145750067885
# 46-60    329767294580
# 60+      103693023717
# Name: Revenue, dtype: int64

# %%
df.groupby('Month')['Revenue'].sum()
# Out:
# Month
# April        65272695656
# August       69981808090
# December     74076921654
# February     69591728848
# January      60305839656
# July         62170400601
# June         65774984427
# March        89507171995
# May          76990989721
# November     67667235458
# October      82148563202
# September    80905088678
# Name: Revenue, dtype: int64

# %%
monthly=df.groupby('Month')['Revenue'].sum()
monthly.plot(kind='line',marker='o',figsize=(10,5))
plt.title('Monthly Revenue Trend')
plt.show()

# %%
df.groupby('Quarter')['Revenue'].sum()
# Out:
# Quarter
# 1    219404740499
# 2    208038669804
# 3    213057297369
# 4    223892720314
# Name: Revenue, dtype: int64

# %% [markdown]
# pd.pivot_table(df,values='Revenue',index='Customer_State',columns='Category',aggfunc='sum')

# %% [markdown]
# 1. Phone generates highest revenue.
# 2. TamilNadu Generates highest sales.
# 3. Card is most preferred mode.
# 4. Age group 18-25 contributed highest Revenue.
# 5. Q4 is the best performing quarter.

# %% [markdown]
# 1. Increase inventory for top-selling products.
# 2. Focus marketing in top-performing states.
# 3. Launch loyalty program for top customers.
# 4. Promote UPI offers.
# 5. Replicate Q4 strategies throughout the year.

# %%
df.groupby("Customer_State")["Revenue"].sum().sort_values(ascending=False)
# Out:
# Customer_State
# Tamil Nadu        190558095125
# Kerala            175691173720
# Telangana         172570501123
# Karnataka         168299747922
# Andhra Pradesh    157273910096
# Name: Revenue, dtype: int64

# %%
state_revenue = df.groupby("Customer_State")["Revenue"].sum().sort_values(ascending=False)

state_revenue.plot(
    kind="bar",
    figsize=(8,5)
)

plt.title("Revenue by State")
plt.xlabel("State")
plt.ylabel("Revenue")
plt.show()
